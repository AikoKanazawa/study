# %%
from sympy import *

t = Symbol('t')

A = Matrix([[0,t],[t,1]])
A.eigenvals()
A.eigenvects()
print(A.eigenvals())
print(A.eigenvects())
# Out:
# {1/2 - sqrt(4*t**2 + 1)/2: 1, sqrt(4*t**2 + 1)/2 + 1/2: 1}
# [(1/2 - sqrt(4*t**2 + 1)/2, 1, [Matrix([
# [(1/2 - sqrt(4*t**2 + 1)/2)/t - 1/t],
# [                                 1]])]), (sqrt(4*t**2 + 1)/2 + 1/2, 1, [Matrix([
# [(sqrt(4*t**2 + 1)/2 + 1/2)/t - 1/t],
# [                                 1]])])]

# %%
import numpy as np

# %%
import math

# %%
import matplotlib.pyplot as plt

# %%
from sympy import *
t = Symbol('t')
x = (0.5 + sqrt(4*t**2 + 1)/2)/t - 1/t
f = (x**2+1)**(-0.5)
print(f)
# Out:
# (((sqrt(4*t**2 + 1)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5)

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$|\phi_1^{(n)}|^2$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$|U_{in}|^2$", fontsize=15)

axes.set_xlim([0, 10])
axes.set_ylim([0, 1])
axes.set_xticks(np.linspace(0, 10, 11))
axes.set_yticks(np.linspace(0, 1, 21))
axes.grid()

x = np.linspace(0.001, 10, 100)

def y1(x):
    return ((0.5 - (4*x**2 + 1)**(0.5)/2)/x - 1/x)*((((0.5 - (4*x**2 + 1)**(0.5)/2)/x - 1/x)**2 + 1)**(-0.5))

def y2(x):
    return (((4*x**2 + 1)**(0.5)/2 + 0.5)/x - 1/x)*(((((4*x**2 + 1)**(0.5)/2 + 0.5)/x - 1/x)**2 + 1)**(-0.5))

ims=[]
im1 = axes.plot(x, y1(x)**2, color='orange')
im2 = axes.plot(x, y2(x)**2, color='blue')
axes.legend(['$E_1$','$E_2$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$|\phi_2^{(n)}|^2$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$|U_{in}|^2$", fontsize=15)

axes.set_xlim([0, 10])
axes.set_ylim([0, 1])
axes.set_xticks(np.linspace(0, 10, 11))
axes.set_yticks(np.linspace(0, 1, 21))
axes.grid()

x = np.linspace(0.001, 10, 100)

def y1(x):
    return (((0.5 - (4*x**2 + 1)**(0.5)/2)/x - 1/x)**2 + 1)**(-0.5)

def y2(x):
    return ((((4*x**2 + 1)**(0.5)/2 + 0.5)/x - 1/x)**2 + 1)**(-0.5)

ims=[]
im1 = axes.plot(x, y1(x)**2, color='orange')
im2 = axes.plot(x, y2(x)**2, color='blue')
axes.legend(['$E_1$','$E_2$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$Energy \quad Spector$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$E_n$", fontsize=15)

axes.set_xlim([0, 5])
axes.set_ylim([-5, 5])
axes.set_xticks(np.linspace(0, 5, 11))
axes.set_yticks(np.linspace(-5, 5, 11))
axes.grid()

x = np.linspace(0, 5, 100)

def y1(x):
    return 1/2 - (4*x**2 + 1)**0.5/2

def y2(x):
    return 1/2 + (4*x**2 + 1)**0.5/2


ims=[]
im1 = axes.plot(x, y1(x), color='orange')
im2 = axes.plot(x, y2(x), color='blue')
axes.legend(['$E_1$','$E_2$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)
axes[0].set_title(r"$Charge \quad distribution(t=0.1,\beta =0.1)$")
axes[0].set_xlabel(r"$x$", fontsize=15) 
axes[0].set_ylabel(r"$y$", fontsize=15)

axes[0].set_xlim([-2, 2])
axes[0].set_ylim([-2, 2])
axes[0].set_xticks(np.linspace(-2, 2, 11))
axes[0].set_yticks(np.linspace(-2, 2, 11))
axes[0].grid()

axes[1].set_title(r"$Charge \quad distribution(t=0.1,\beta =1)$")
axes[1].set_xlabel(r"$x$", fontsize=15) 
axes[1].set_ylabel(r"$y$", fontsize=15)

axes[1].set_xlim([-2, 2])
axes[1].set_ylim([-2, 2])
axes[1].set_xticks(np.linspace(-2, 2, 11))
axes[1].set_yticks(np.linspace(-2, 2, 11))
axes[1].grid()

axes[2].set_title(r"$Charge \quad distribution(t=0.1,\beta =10)$")
axes[2].set_xlabel(r"$x$", fontsize=15) 
axes[2].set_ylabel(r"$y$", fontsize=15)

axes[2].set_xlim([-2, 2])
axes[2].set_ylim([-2, 2])
axes[2].set_xticks(np.linspace(-2, 2, 11))
axes[2].set_yticks(np.linspace(-2, 2, 11))
axes[2].grid()

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

def T11(t):
    return ((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)*((((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5))

def T12(t):
    return (((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)*(((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5))

def T21(t):
    return (((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5)

def T22(t):
    return ((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

b = 0.1
t = 0.1

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P0 = f*(R1+R2)

b = 1
t = 0.1

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P1 = f*(R1+R2)

b = 10
t = 0.1

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P2 = f*(R1+R2)

axes[0].contourf(X, Y, P0, cmap='jet')
axes[1].contourf(X, Y, P1, cmap='jet')
axes[2].contourf(X, Y, P2, cmap='jet')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)
axes[0].set_title(r"$Charge \quad distribution(t=0.1,\beta =0.1)$")
axes[0].set_xlabel(r"$x$", fontsize=15) 
axes[0].set_ylabel(r"$y$", fontsize=15)

axes[0].set_xlim([-2, 2])
axes[0].set_ylim([-2, 2])
axes[0].set_xticks(np.linspace(-2, 2, 11))
axes[0].set_yticks(np.linspace(-2, 2, 11))
axes[0].grid()

axes[1].set_title(r"$Charge \quad distribution(t=0.1,\beta =1)$")
axes[1].set_xlabel(r"$x$", fontsize=15) 
axes[1].set_ylabel(r"$y$", fontsize=15)

axes[1].set_xlim([-2, 2])
axes[1].set_ylim([-2, 2])
axes[1].set_xticks(np.linspace(-2, 2, 11))
axes[1].set_yticks(np.linspace(-2, 2, 11))
axes[1].grid()

axes[2].set_title(r"$Charge \quad distribution(t=0.1,\beta =10)$")
axes[2].set_xlabel(r"$x$", fontsize=15) 
axes[2].set_ylabel(r"$y$", fontsize=15)

axes[2].set_xlim([-2, 2])
axes[2].set_ylim([-2, 2])
axes[2].set_xticks(np.linspace(-2, 2, 11))
axes[2].set_yticks(np.linspace(-2, 2, 11))
axes[2].grid()

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

def T11(t):
    return ((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)*((((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5))

def T12(t):
    return (((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)*(((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5))

def T21(t):
    return (((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5)

def T22(t):
    return ((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

b = 0.1
t = 1

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P0 = f*(R1+R2)

b = 1
t = 1

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P1 = f*(R1+R2)

b = 10
t = 1

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P2 = f*(R1+R2)

axes[0].contourf(X, Y, P0, cmap='jet')
axes[1].contourf(X, Y, P1, cmap='jet')
axes[2].contourf(X, Y, P2, cmap='jet')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)
axes[0].set_title(r"$Charge \quad distribution(t=0.1,\beta =0.1)$")
axes[0].set_xlabel(r"$x$", fontsize=15) 
axes[0].set_ylabel(r"$y$", fontsize=15)

axes[0].set_xlim([-2, 2])
axes[0].set_ylim([-2, 2])
axes[0].set_xticks(np.linspace(-2, 2, 11))
axes[0].set_yticks(np.linspace(-2, 2, 11))
axes[0].grid()

axes[1].set_title(r"$Charge \quad distribution(t=0.1,\beta =1)$")
axes[1].set_xlabel(r"$x$", fontsize=15) 
axes[1].set_ylabel(r"$y$", fontsize=15)

axes[1].set_xlim([-2, 2])
axes[1].set_ylim([-2, 2])
axes[1].set_xticks(np.linspace(-2, 2, 11))
axes[1].set_yticks(np.linspace(-2, 2, 11))
axes[1].grid()

axes[2].set_title(r"$Charge \quad distribution(t=0.1,\beta =10)$")
axes[2].set_xlabel(r"$x$", fontsize=15) 
axes[2].set_ylabel(r"$y$", fontsize=15)

axes[2].set_xlim([-2, 2])
axes[2].set_ylim([-2, 2])
axes[2].set_xticks(np.linspace(-2, 2, 11))
axes[2].set_yticks(np.linspace(-2, 2, 11))
axes[2].grid()

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

def T11(t):
    return ((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)*((((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5))

def T12(t):
    return (((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)*(((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5))

def T21(t):
    return (((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5)

def T22(t):
    return ((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

b = 0.1
t = 10

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P0 = f*(R1+R2)

b = 1
t = 10

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P1 = f*(R1+R2)

b = 10
t = 10

f = (B1(b)+B2(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
P2 = f*(R1+R2)

axes[0].contourf(X, Y, P0, cmap='jet')
axes[1].contourf(X, Y, P1, cmap='jet')
axes[2].contourf(X, Y, P2, cmap='jet')

plt.show()

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

def T11(t):
    return ((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)*((((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5))

def T12(t):
    return (((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)*(((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5))

def T21(t):
    return (((0.5 - (4*t**2 + 1)**(0.5)/2)/t - 1/t)**2 + 1)**(-0.5)

def T22(t):
    return ((((4*t**2 + 1)**(0.5)/2 + 0.5)/t - 1/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

numbers = [1,0,-1]
Numbers = [-1,0,1]

t_list = [10 ** k for k in numbers]
b_list = [10 ** l for l in Numbers]

P0 = [[None for _ in range(3)] for _ in range (3)]
for i, t in enumerate(t_list):
    for j, b in enumerate(b_list):
        f = (B1(b)+B2(b))**-1
        R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t))
        R2 = np.exp(-np.pi*((X)**2 + (Y-1)**2))*(B1(b)*T21(t)*T21(t)+B2(b)*T22(t)*T22(t))
        P0[i][j] = f*(R1+R2)

fig, axes = plt.subplots(3, 3, figsize=(15, 15), constrained_layout=True)
for i in range(3):
    for j in range(3):
        axes[i][j].set_title(r"$Charge \quad distribution$")
        axes[i][j].set_xlabel(r"$x$", fontsize=15) 
        axes[i][j].set_ylabel(r"$y$", fontsize=15)

        axes[i][j].set_xlim([-2, 2])
        axes[i][j].set_ylim([-2, 2])
        axes[i][j].set_xticks(np.linspace(-2, 2, 11))
        axes[i][j].set_yticks(np.linspace(-2, 2, 11))
        axes[i][j].grid()
        l = P0[i][j]
        axes[i][j].contourf(X, Y, l, cmap='jet')

# %%
numbers = [-1,0,1]

t_list = [10 ** j for j in numbers]
b_list = [10 ** k for k in numbers]

for t, b in zip(t_list, b_list):
    print(t, b )
# Out:
# 0.1 0.1
# 1 1
# 10 10

# %%
numbers = [-1,0,1]

t_list = [10 ** j for j in numbers]
b_list = [10 ** k for k in numbers]

for t in t_list:
    for b in b_list:
        print(t, b)
# Out:
# 0.1 0.1
# 0.1 1
# 0.1 10
# 1 0.1
# 1 1
# 1 10
# 10 0.1
# 10 1
# 10 10
