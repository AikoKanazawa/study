# %%
import numpy as np

# %%
import math

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
# axes.set_title(r"$Energy \quad Spectrum \quad (H_{1s,1s}=0,H_{2s,2s}=1)$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$E_{n'}$", fontsize=15, rotation=0)

axes.set_xlim([0, 5])
axes.set_ylim([-10, 10])
axes.set_xticks(np.linspace(0, 5, 11))
axes.set_yticks(np.linspace(-10, 10, 11))
axes.grid()

x = np.linspace(0, 5, 100)

def y1(x):
    return 1/2 - (16*x**2 + 1)**0.5/2

def y2(x):
    return 1/2 + (16*x**2 + 1)**0.5/2


ims=[]
im1 = axes.plot(x, y1(x), color='orange')
im2 = axes.axhline(0, ls = "-", color = 'magenta')
im3 = axes.plot(x, y2(x), color='blue')
im4 = axes.axhline(2, ls = "-", color = 'green')
axes.legend(['$E_1$','$E_2$', '$E_3$', '$E_4$'])

plt.show()

# %%
from sympy import *
x = Symbol('x')
t = (0.25*(0.5 + 2.0*(x**2 + 0.0625)**0.5)/x - 0.25/x)
T = t*t
f = (4*T+1)**(-0.5)
print(f)
# Out:
# (4*((0.5*(x**2 + 0.0625)**0.5 + 0.125)/x - 0.25/x)**2 + 1)**(-0.5)

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
# axes.set_title(r"$|\phi_{1s}^{(n)}|^2=|\phi_{1s_2}^{(n)}|^2=|\phi_{1s_3}^{(n)}|^2=|\phi_{1s_4}^{(n)}|^2$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$|\phi_{1s}^{(n)}|^2$", fontsize=15, rotation=0)

axes.set_xlim([0, 10])
axes.set_ylim([0, 1])
axes.set_xticks(np.linspace(0, 10, 11))
axes.set_yticks(np.linspace(0, 1, 5))
axes.grid()

x = np.linspace(0.001, 10, 100)

def y1(x):
    return (0.25*(0.5 - 2.0*(x**2 + 0.0625)**0.5)/x - 0.25/x)*((4*((0.125 - 0.5*(x**2 + 0.0625)**0.5)/x - 0.25/x)**2 + 1)**(-0.5))

def y2(x):
    return (0.25*(0.5 + 2.0*(x**2 + 0.0625)**0.5)/x - 0.25/x)*((4*((0.5*(x**2 + 0.0625)**0.5 + 0.125)/x - 0.25/x)**2 + 1)**(-0.5))

ims=[]
im1 = axes.plot(x, y1(x)**2, color='orange')
im2 = axes.axhline(0.5, color = 'magenta')
im3 = axes.plot(x, y2(x)**2, color='blue')
axes.legend(['$E_1$','$E_2$', '$E_3$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
# axes.set_title(r"$|\phi_{2s}^{(n)}|^2$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$|\phi_{2s}^{(n)}|^2$", fontsize=15, rotation=0)

axes.set_xlim([0, 10])
axes.set_ylim([0, 1])
axes.set_xticks(np.linspace(0, 10, 11))
axes.set_yticks(np.linspace(0, 1, 5))
axes.grid()

x = np.linspace(0.001, 10, 100)

def y1(x):
    return (4*((0.125 - 0.5*(x**2 + 0.0625)**0.5)/x - 0.25/x)**2 + 1)**(-0.5)

def y2(x):
    return (4*((0.5*(x**2 + 0.0625)**0.5 + 0.125)/x - 0.25/x)**2 + 1)**(-0.5)

ims=[]
im1 = axes.plot(x, y1(x)**2, color='orange')
im2 = axes.plot(x, y2(x)**2, color='blue')
axes.legend(['$E_1$','$E_3$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
# axes.set_title(r"$|\phi_{2p}^{(n)}|^2$")
axes.set_xlabel(r"$t$", fontsize=15) 
axes.set_ylabel(r"$|\phi_{2p}^{(n)}|^2$", fontsize=15, rotation=0)

axes.set_xlim([0, 10])
axes.set_ylim([0, 2])
axes.set_xticks(np.linspace(0, 10, 11))
axes.set_yticks(np.linspace(0, 2, 11))
axes.grid()

x = np.linspace(0.001, 10, 100)

ims=[]
im1 = axes.axhline(1, color = 'green')
axes.legend(['$E_4$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)
axes[0].set_title(r"$Charge \quad distribution(t=0.1,\beta =0.1)$")
axes[0].set_xlabel(r"$x$", fontsize=15) 
axes[0].set_ylabel(r"$y$", fontsize=15)

axes[0].set_xlim([-2, 2])
axes[0].set_ylim([-2, 2])
axes[0].set_xticks(np.linspace(-2, 2, 11))
axes[0].set_yticks(np.linspace(-2, 2, 11))
axes[0].grid()

axes[1].set_title(r"$Charge \quad distribution(t=0.1,\beta =1)$")
axes[1].set_xlabel(r"$x$", fontsize=15) 
axes[1].set_ylabel(r"$y$", fontsize=15)

axes[1].set_xlim([-2, 2])
axes[1].set_ylim([-2, 2])
axes[1].set_xticks(np.linspace(-2, 2, 11))
axes[1].set_yticks(np.linspace(-2, 2, 11))
axes[1].grid()

axes[2].set_title(r"$Charge \quad distribution(t=0.1,\beta =10)$")
axes[2].set_xlabel(r"$x$", fontsize=15) 
axes[2].set_ylabel(r"$y$", fontsize=15)

axes[2].set_xlim([-2, 2])
axes[2].set_ylim([-2, 2])
axes[2].set_xticks(np.linspace(-2, 2, 11))
axes[2].set_yticks(np.linspace(-2, 2, 11))
axes[2].grid()

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

E3 = 0

def T11(t):
    return (0.25*(0.5 - 2.0*(t**2 + 0.0625)**0.5)/t - 0.25/t)*((4*((0.125 - 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5))

def T12(t):
    return (0.25*(0.5 + 2.0*(t**2 + 0.0625)**0.5)/t - 0.25/t)*((4*((0.125 + 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5))

T13 = 1/(2**(0.5))

def T51(t):
    return (4*((0.125 - 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5)

def T52(t):
    return (4*((0.125 + 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

def B3(b):
    return np.exp(-b*E3)

b = 0.1
t = 0.1

f = (B1(b)+B2(b)+B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P0 = f*(R1+R2+R3+R4+R5)

b = 1
t = 0.1

f = (B1(b)+B2(b)+B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P1 = f*(R1+R2+R3+R4+R5)

b = 10
t = 0.1

f = (B1(b)+B2(b)+B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P2 = f*(R1+R2+R3+R4+R5)

axes[0].contourf(X, Y, P0, cmap='jet')
axes[1].contourf(X, Y, P1, cmap='jet')
axes[2].contourf(X, Y, P2, cmap='jet')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)
axes[0].set_title(r"$Charge \quad distribution(t=1,\beta =0.1)$")
axes[0].set_xlabel(r"$x$", fontsize=15) 
axes[0].set_ylabel(r"$y$", fontsize=15)

axes[0].set_xlim([-2, 2])
axes[0].set_ylim([-2, 2])
axes[0].set_xticks(np.linspace(-2, 2, 11))
axes[0].set_yticks(np.linspace(-2, 2, 11))
axes[0].grid()

axes[1].set_title(r"$Charge \quad distribution(t=1,\beta =1)$")
axes[1].set_xlabel(r"$x$", fontsize=15) 
axes[1].set_ylabel(r"$y$", fontsize=15)

axes[1].set_xlim([-2, 2])
axes[1].set_ylim([-2, 2])
axes[1].set_xticks(np.linspace(-2, 2, 11))
axes[1].set_yticks(np.linspace(-2, 2, 11))
axes[1].grid()

axes[2].set_title(r"$Charge \quad distribution(t=1,\beta =10)$")
axes[2].set_xlabel(r"$x$", fontsize=15) 
axes[2].set_ylabel(r"$y$", fontsize=15)

axes[2].set_xlim([-2, 2])
axes[2].set_ylim([-2, 2])
axes[2].set_xticks(np.linspace(-2, 2, 11))
axes[2].set_yticks(np.linspace(-2, 2, 11))
axes[2].grid()

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

E3 = 0

def T11(t):
    return (0.25*(0.5 - 2.0*(t**2 + 0.0625)**0.5)/t - 0.25/t)*((4*((0.125 - 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5))

def T12(t):
    return (0.25*(0.5 + 2.0*(t**2 + 0.0625)**0.5)/t - 0.25/t)*((4*((0.125 + 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5))

T13 = 1/(2**(0.5))

def T51(t):
    return (4*((0.125 - 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5)

def T52(t):
    return (4*((0.125 + 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

def B3(b):
    return np.exp(-b*E3)

b = 0.1
t = 1

f = (B1(b)*B2(b)*B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P0 = f*(R1+R2+R3+R4+R5)

b = 1
t = 1

f = (B1(b)*B2(b)*B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P1 = f*(R1+R2+R3+R4+R5)

b = 10
t = 1

f = (B1(b)*B2(b)*B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P2 = f*(R1+R2+R3+R4+R5)

axes[0].contourf(X, Y, P0, cmap='jet')
axes[1].contourf(X, Y, P1, cmap='jet')
axes[2].contourf(X, Y, P2, cmap='jet')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)
axes[0].set_title(r"$Charge \quad distribution(t=10,\beta =0.1)$")
axes[0].set_xlabel(r"$x$", fontsize=15) 
axes[0].set_ylabel(r"$y$", fontsize=15)

axes[0].set_xlim([-2, 2])
axes[0].set_ylim([-2, 2])
axes[0].set_xticks(np.linspace(-2, 2, 11))
axes[0].set_yticks(np.linspace(-2, 2, 11))
axes[0].grid()

axes[1].set_title(r"$Charge \quad distribution(t=10,\beta =1)$")
axes[1].set_xlabel(r"$x$", fontsize=15) 
axes[1].set_ylabel(r"$y$", fontsize=15)

axes[1].set_xlim([-2, 2])
axes[1].set_ylim([-2, 2])
axes[1].set_xticks(np.linspace(-2, 2, 11))
axes[1].set_yticks(np.linspace(-2, 2, 11))
axes[1].grid()

axes[2].set_title(r"$Charge \quad distribution(t=10,\beta =10)$")
axes[2].set_xlabel(r"$x$", fontsize=15) 
axes[2].set_ylabel(r"$y$", fontsize=15)

axes[2].set_xlim([-2, 2])
axes[2].set_ylim([-2, 2])
axes[2].set_xticks(np.linspace(-2, 2, 11))
axes[2].set_yticks(np.linspace(-2, 2, 11))
axes[2].grid()

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x,y)

def E1(t):
    return 1/2 - (16*t**2 + 1)**0.5/2

def E2(t):
    return 1/2 + (16*t**2 + 1)**0.5/2

E3 = 0

def T11(t):
    return (0.25*(0.5 - 2.0*(t**2 + 0.0625)**0.5)/t - 0.25/t)*((4*((0.125 - 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5))

def T12(t):
    return (0.25*(0.5 + 2.0*(t**2 + 0.0625)**0.5)/t - 0.25/t)*((4*((0.125 + 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5))

T13 = 1/(2**(0.5))

def T51(t):
    return (4*((0.125 - 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5)

def T52(t):
    return (4*((0.125 + 0.5*(t**2 + 0.0625)**0.5)/t - 0.25/t)**2 + 1)**(-0.5)

def B1(b):
    return np.exp(-b*E1(t))

def B2(b):
    return np.exp(-b*E2(t))

def B3(b):
    return np.exp(-b*E3)

b = 0.1
t = 10

f = (B1(b)*B2(b)*B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P0 = f*(R1+R2+R3+R4+R5)

b = 1
t = 10

f = (B1(b)*B2(b)*B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P1 = f*(R1+R2+R3+R4+R5)

b = 10
t = 10

f = (B1(b)*B2(b)*B3(b))**-1
R1 = np.exp(-np.pi*((X-1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R2 = np.exp(-np.pi*((X+1)**2 + (Y-1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R3 = np.exp(-np.pi*((X+1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R4 = np.exp(-np.pi*((X-1)**2 + (Y+1)**2))*(B1(b)*T11(t)*T11(t)+B2(b)*T12(t)*T12(t)+B3(b)*T13*T13)
R5 = np.exp(-np.pi*(X**2 + Y**2))*(B1(b)*T51(t)*T51(t)+B2(b)*T52(t)*T52(t))
P2 = f*(R1+R2+R3+R4+R5)

axes[0].contourf(X, Y, P0, cmap='jet')
axes[1].contourf(X, Y, P1, cmap='jet')
axes[2].contourf(X, Y, P2, cmap='jet')

plt.show()
