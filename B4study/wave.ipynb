# %%
import numpy as np

# %%
import math

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)
axes[0].set_title(r"In the case of 0")
axes[1].set_title(r"In the case of 0")
axes[0].set_xlabel(r"$r$", fontsize=15) 
axes[0].set_ylabel(r"$-\phi_{1s_1}+\phi_{1s_{2,3,4}}$", fontsize=15)
axes[1].set_xlabel(r"$r$", fontsize=15) 
axes[1].set_ylabel(r"$(-\phi_{1s_1}+\phi_{1s_{2,3,4}})^2$", fontsize=15)

axes[0].set_xlim([-5, 5])
axes[0].set_ylim([-1, 1])
axes[1].set_xlim([-5, 5])
axes[1].set_ylim([-1, 1])
axes[0].set_xticks(np.linspace(-5, 5, 11))
axes[0].set_yticks(np.linspace(-1, 1, 11))
axes[1].set_xticks(np.linspace(-5, 5, 11))
axes[1].set_yticks(np.linspace(-1, 1, 11))
axes[0].grid()
axes[1].grid()

x = np.linspace(-5, 5, 100)

amp = math.pow(math.pi, -1/2)
y1 = -amp*np.exp(-np.abs(x+1))
y2 = amp*np.exp(-np.abs(x-1))
y3 = y1+y2
axes[0].plot(x, y1, color='gray', linestyle="dashed")
axes[0].plot(x, y2, color='black', linestyle="dashed")
axes[1].plot(x, y3, color='gray', linestyle="dashed")

ims=[]
im1 = axes[0].plot(x, y3, color='red')
im2 = axes[1].plot(x, y3*y3, color='red')
axes[0].legend(['$-\phi_{1s_1}$','$\phi_{1s_2,3,4}$', '$-\phi_{1s_1}+\phi_{1s_{2,3,4}}$'])
axes[1].legend(['$-\phi_{1s_1}+\phi_{1s_{2,3,4}}$', '$(-\phi_{1s_1}+\phi_{1s_{2,3,4}})^2$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)
axes[0].set_title(r"In the case of $0.5 - \sqrt{2.0*(t^2 + 0.0625)}$")
axes[1].set_title(r"In the case of $0.5 - \sqrt{2.0*(t^2 + 0.0625)}$")
axes[0].set_xlabel(r"$r$", fontsize=15) 
axes[0].set_ylabel(r"$(0.25*(0.5 - \sqrt{2.0*(t^2 + 0.0625)})/t - 0.25/t)*(\phi_{1s_1}+\phi_{1s_2}+\phi_{1s_3}+\phi_{1s_4})+\phi_{2s}$", fontsize=7.5)
axes[1].set_xlabel(r"$r$", fontsize=15) 
axes[1].set_ylabel(r"$((0.25*(0.5 - \sqrt{2.0*(t^2 + 0.0625)})/t - 0.25/t)*(\phi_{1s_1}+\phi_{1s_2}+\phi_{1s_3}+\phi_{1s_4})+\phi_{2s})^2$", fontsize=7.5)

axes[0].set_xlim([-5, 5])
axes[0].set_ylim([-2, 3])
axes[1].set_xlim([-5, 5])
axes[1].set_ylim([-2, 8])
axes[0].set_xticks(np.linspace(-5, 5, 11))
axes[0].set_yticks(np.linspace(-2, 3, 11))
axes[1].set_xticks(np.linspace(-5, 5, 11))
axes[1].set_yticks(np.linspace(-2, 8, 11))
axes[0].grid()
axes[1].grid()

x = np.linspace(-5, 5, 100)

amp = math.pow(math.pi, -1/2)
y1 = -0.6403882032022076*amp*np.exp(-np.abs(x+1))
y2 = -0.6403882032022076*amp*np.exp(-np.abs(x-1))
y3 = amp*np.exp(-6*(np.abs(x))/2)*(1/(4*math.sqrt(2)))*(2-6*(np.abs(x)))*math.pow(6, 3/2)
y4 = 2*y1+2*y2+y3
y5 = 0.6403882032022076*amp*np.exp(-np.abs(x+1))
y6 = 0.6403882032022076*amp*np.exp(-np.abs(x-1))
y7 = 2*y5+2*y6+y3
y8 = -0.5663911092686593*amp*np.exp(-np.abs(x+1))
y9 = -0.5663911092686593*amp*np.exp(-np.abs(x-1))
y10 = 2*y8+2*y9+y3
y11 = 0.5663911092686593*amp*np.exp(-np.abs(x+1))
y12 = 0.5663911092686593*amp*np.exp(-np.abs(x-1))
y13 = 2*y11+2*y12+y3
axes[0].plot(x, y3, color='gray', linestyle="dashed")
# axes[1].plot(x, y4, color='gray', linestyle="dashed")
# axes[1].plot(x, y7, color='gray', linestyle="dashed")
# axes[1].plot(x, y10, color='gray', linestyle="dashed")
# axes[1].plot(x, y13, color='gray', linestyle="dashed")

ims=[]
im1 = axes[0].plot(x, y4, color='orange', label="a")
# im2 = axes[0].plot(x, y7, color='green')
im3 = axes[0].plot(x, y10, color='blue')
# im4 = axes[0].plot(x, y13, color='red')
im5 = axes[1].plot(x, y4*y4, color='orange')
# im6 = axes[1].plot(x, y7*y7, color='green')
im7 = axes[1].plot(x, y10*y10, color='blue')
# im8 = axes[1].plot(x, y13*y13, color='red')
# axes[0].legend(['$\phi_{2s}$','t=1', 't=-1', 't=2', 't=-2'])
# axes[1].legend(['t=1', 't=-1', 't=2', 't=-2'])
axes[0].legend(['$\phi_{2s}$','t=1', 't=2'])
axes[1].legend(['t=1', 't=2'])

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)
axes[0].set_title(r"In the case of $0.5 + \sqrt{2.0*(t^2 + 0.0625)}$")
axes[1].set_title(r"In the case of $0.5 + \sqrt{2.0*(t^2 + 0.0625)}$")
axes[0].set_xlabel(r"$r$", fontsize=15) 
axes[0].set_ylabel(r"$(0.25*(0.5 + \sqrt{2.0*(t^2 + 0.0625)})/t - 0.25/t)*(\phi_{1s_1}+\phi_{1s_2}+\phi_{1s_3}+\phi_{1s_4})+\phi_{2s}$", fontsize=7.5)
axes[1].set_xlabel(r"$r$", fontsize=15) 
axes[1].set_ylabel(r"$(0.25*(0.5 + \sqrt{2.0*(t^2 + 0.0625)})/t - 0.25/t)*(\phi_{1s_1}+\phi_{1s_2}+\phi_{1s_3}+\phi_{1s_4})+\phi_{2s}$", fontsize=7.5)

axes[0].set_xlim([-5, 5])
axes[0].set_ylim([-2, 3])
axes[1].set_xlim([-5, 5])
axes[1].set_ylim([-2, 8])
axes[0].set_xticks(np.linspace(-5, 5, 11))
axes[0].set_yticks(np.linspace(-2, 3, 11))
axes[1].set_xticks(np.linspace(-5, 5, 11))
axes[1].set_yticks(np.linspace(-2, 8, 11))
axes[0].grid()
axes[1].grid()

x = np.linspace(-5, 5, 100)

amp = math.pow(math.pi, -1/2)
y1 = 0.3903882032022076*amp*np.exp(-np.abs(x+1))
y2 = 0.3903882032022076*amp*np.exp(-np.abs(x-1))
y3 = amp*np.exp(-6*(np.abs(x))/2)*(1/(4*math.sqrt(2)))*(2-6*(np.abs(x)))*math.pow(6, 3/2)
y4 = 2*y1+2*y2+y3
y5 = -0.3903882032022076*amp*np.exp(-np.abs(x+1))
y6 = -0.3903882032022076*amp*np.exp(-np.abs(x-1))
y7 = 2*y5+2*y6+y3
y8 = 0.4413911092686593*amp*np.exp(-np.abs(x+1))
y9 = 0.4413911092686593*amp*np.exp(-np.abs(x-1))
y10 = 2*y8+2*y9+y3
y11 = -0.4413911092686593*amp*np.exp(-np.abs(x+1))
y12 = -0.4413911092686593*amp*np.exp(-np.abs(x-1))
y13 = 2*y11+2*y12+y3
axes[0].plot(x, y3, color='gray', linestyle="dashed")
# axes[1].plot(x, y4, color='gray', linestyle="dashed")
# axes[1].plot(x, y7, color='gray', linestyle="dashed")
# axes[1].plot(x, y10, color='gray', linestyle="dashed")
# axes[1].plot(x, y13, color='gray', linestyle="dashed")

ims=[]
im1 = axes[0].plot(x, y4, color='orange', label="a")
# im2 = axes[0].plot(x, y7, color='green')
im3 = axes[0].plot(x, y10, color='blue')
# im4 = axes[0].plot(x, y13, color='red')
im5 = axes[1].plot(x, y4*y4, color='orange')
# im6 = axes[1].plot(x, y7*y7, color='green')
im7 = axes[1].plot(x, y10*y10, color='blue')
# im8 = axes[1].plot(x, y13*y13, color='red')
# axes[0].legend(['$\phi_{2s}$','t=1', 't=-1', 't=2', 't=-2'])
# axes[1].legend(['t=1', 't=-1', 't=2', 't=-2'])
axes[0].legend(['$\phi_{2s}$','t=1', 't=2'])
axes[1].legend(['t=1', 't=2'])

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)
axes[0].set_title(r"In the case of 1.5")
axes[1].set_title(r"In the case of 1.5")
axes[0].set_xlabel(r"$r$", fontsize=15) 
axes[0].set_ylabel(r"$\phi_{2p_{x,y,z}}$", fontsize=15)
axes[1].set_xlabel(r"$r$", fontsize=15) 
axes[1].set_ylabel(r"${\phi_{2p_{x,y,z}}}^2$", fontsize=15)

axes[0].set_xlim([-5, 5])
axes[0].set_ylim([-2.5, 2.5])
axes[1].set_xlim([-5, 5])
axes[1].set_ylim([-2, 8])
axes[0].set_xticks(np.linspace(-5, 5, 11))
axes[0].set_yticks(np.linspace(-2.5, 2.5, 11))
axes[1].set_xticks(np.linspace(-5, 5, 11))
axes[1].set_yticks(np.linspace(-2, 8, 11))
axes[0].grid()
axes[1].grid()

x1 = np.linspace(0, 5, 100)
x2 = np.linspace(-5, 0, 100)

# amp = math.pow(math.pi, -1/2)
y1 = np.exp(-6*np.abs(x1)/2)*6*np.abs(x1)*6/2
y2 = -np.exp(-6*np.abs(x2)/2)*6*np.abs(x2)*6/2

ims=[]
im1 = axes[0].plot(x1, y1, color='orange')
im2 = axes[0].plot(x2, y2, color='orange')
im3 = axes[1].plot(x1, y1*y1, color='orange')
im3 = axes[1].plot(x2, y2*y2, color='orange')

plt.show()
