# %%
import numpy as np

# %%
import math

# %%
import matplotlib.pyplot as plt

# %%
import sympy

# %%
from sympy import *

# %%
import matplotlib.animation as animation

# %%
x = np.linspace(0, 360, 100)

a = (-8.542)*10**(-4)
b = (1.146)*10**(-4)
c = 0
d = (8.830)*10**(-4)

def xy1(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x))

def xy2r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

def xy2l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )


def zx1(x):
    return (c+a)/2+(c-a)/2*np.cos(2*np.radians(x))

def zx2(x):
    return (4*c+a+3*b)/8+(4*c-(a+3*b))/8*np.cos(2*np.radians(x))+3**(1/2)/2*d*np.sin(2*np.radians(x))

def zx3(x):
    return (4*c+a+3*b)/8+(4*c-(a+3*b))/8*np.cos(2*np.radians(x))-3**(1/2)/2*d*np.sin(2*np.radians(x))


def yz1r(x):
    return (c+b)/2+(c-b)/2*np.cos(2*np.radians(x)) + d*np.sin(2*np.radians(x))

def yz1l(x):
    return (c+b)/2+(c-b)/2*np.cos(2*np.radians(x)) - d*np.sin(2*np.radians(x))

def yz23r(x):
    return (4*c+3*a+b)/8+(4*c-(3*a+b))/8*np.cos(2*np.radians(x))-d/2*np.sin(2*np.radians(x))

def yz23l(x):
    return (4*c+3*a+b)/8+(4*c-(3*a+b))/8*np.cos(2*np.radians(x))+d/2*np.sin(2*np.radians(x))

#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure()

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(4, 2, 1)
ax2 = fig.add_subplot(4, 2, 2)
ax3 = fig.add_subplot(4, 2, 3)
ax4 = fig.add_subplot(4, 2, 4)
ax5 = fig.add_subplot(4, 2, 5)
ax6 = fig.add_subplot(4, 2, 6)
ax7 = fig.add_subplot(4, 2, 7)
ax8 = fig.add_subplot(4, 2, 8)

ax1.plot(x, xy1(x)*10**4, color='yellow')
ax1.set_xlabel(r"$Rotation \quad angle$") 
ax1.set_ylabel(r"$K(\times 10^4)$") 
ax1.set_title('xy1')

ax2.plot(x, xy2r(x)*10**4, color='red')
ax2.plot(x, xy2l(x)*10**4, color='blue')
ax2.set_xlabel(r"$Rotation \quad angle$") 
ax2.set_ylabel(r"$K(\times 10^4)$") 
ax2.set_title('xy2r,xy2l')

ax3.plot(x, xy3r(x)*10**4, color='red', label=xy3r)
ax3.plot(x, xy3l(x)*10**4, color='blue', label=xy3l)
ax3.set_xlabel(r"$Rotation \quad angle$") 
ax3.set_ylabel(r"$K(\times 10^4)$") 
ax3.set_title('xy3r,xy3l')

ax4.plot(x, zx1(x)*10**4, color='yellow', label=zx1)
ax4.set_xlabel(r"$Rotation \quad angle$") 
ax4.set_ylabel(r"$K(\times 10^4)$") 
ax4.set_title('zx1')

ax5.plot(x, zx2(x)*10**4, color='yellow', label=zx2)
ax5.set_xlabel(r"$Rotation \quad angle$") 
ax5.set_ylabel(r"$K(\times 10^4)$") 
ax5.set_title('zx2')

ax6.plot(x, zx3(x)*10**4, color='yellow', label=zx3)
ax6.set_xlabel(r"$Rotation \quad angle$") 
ax6.set_ylabel(r"$K(\times 10^4)$") 
ax6.set_title('zx3')

ax7.plot(x, yz1r(x)*10**4, color='red', label=yz1r)
ax7.plot(x, yz1l(x)*10**4, color='blue', label=yz1l)
ax7.set_xlabel(r"$Rotation \quad angle$") 
ax7.set_ylabel(r"$K(\times 10^4)$") 
ax7.set_title('yz1r,yz1l')

ax8.plot(x, yz23r(x)*10**4, color='red', label=yz23r)
ax8.plot(x, yz23l(x)*10**4, color='blue', label=yz23l)
ax8.set_xlabel(r"$Rotation \quad angle$") 
ax8.set_ylabel(r"$K(\times 10^4)$") 
ax8.set_title('yz23r,yz23l')

fig.tight_layout()              #レイアウトの設定
plt.show()

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
R = sympy.Matrix([[3**(0.5)/2, -0.5, 0], [0.5, 3**(0.5)/2, 0], [0, 0, 1]])
A = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])

f = R*A*R**(-1)

print(f)
# Out:
# Matrix([[0.75*X + 0.25*Y, 0.433012701892219*X - 0.433012701892219*Y, 0.866025403784439*W], [0.433012701892219*X - 0.433012701892219*Y, 0.25*X + 0.75*Y, 0.5*W], [0.866025403784439*W, 0.5*W, Z]])

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
R = sympy.Matrix([[3**(0.5)/2, 0.5, 0], [-0.5, 3**(0.5)/2, 0], [0, 0, 1]])
A = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])

f = R*A*R**(-1)

print(f)
# Out:
# Matrix([[0.75*X + 0.25*Y, -0.433012701892219*X + 0.433012701892219*Y, 0.866025403784439*W], [-0.433012701892219*X + 0.433012701892219*Y, 0.25*X + 0.75*Y, -0.5*W], [0.866025403784439*W, -0.5*W, Z]])

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
C = Symbol('C')
S = Symbol('S')
R = sympy.Matrix([[C, S, 0]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[C], [S], [0]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[C*(C*(3*X/4 + Y/4) + S*(0.433012701892219*X - 0.433012701892219*Y)) + S*(C*(0.433012701892219*X - 0.433012701892219*Y) + S*(X/4 + 3*Y/4))]])
# Matrix([[C**2*X + S**2*Y]])
# Matrix([[C*(C*(3*X/4 + Y/4) + S*(-0.433012701892219*X + 0.433012701892219*Y)) + S*(C*(-0.433012701892219*X + 0.433012701892219*Y) + S*(X/4 + 3*Y/4))]])

# %%
a = (-8.572)*10**(-4)
b = (1.146)*10**(-4)
c = 0
d = (8.830)*10**(-4)

def xy1(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x))

def xy2r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

def xy2l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

print(xy1(0)*10**(4))
print(xy2r(0)*10**(4))
print(xy3r(0)*10**(4))
# Out:
# -8.572
# -1.2834999999999979
# -1.2834999999999979

# %%
init_printing()

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
R = sympy.Matrix([[3**(0.5)/2, 0.5, 0]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[3**(0.5)/2], [0.5], [0]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[1.0*X + 2.77555756156289e-17*Y]])
# Matrix([[0.75*X + 0.25*Y]])
# Matrix([[0.25*X + 0.75*Y]])

# %%
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
d = Symbol('d')

def xy1(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x))

def xy2r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

def xy2l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

print(xy1(0))
print(xy2r(0))
print(xy3r(0))
# Out:
# 1.0*a
# 0.25*a + 0.75*b
# 0.25*a + 0.75*b

# %%
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
d = Symbol('d')

def xy1(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x))

def xy2r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

def xy2l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

print(xy1(330))
print(xy2r(330))
print(xy3r(330))
# Out:
# 0.75*a + 0.25*b
# 1.0*b
# 0.75*a + 0.25*b

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
R = sympy.Matrix([[1, 0, 0]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[1], [0], [0]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[3*X/4 + Y/4]])
# Matrix([[X]])
# Matrix([[3*X/4 + Y/4]])

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
C = Symbol('C')
S = Symbol('S')
R = sympy.Matrix([[0, C, S]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[0], [C], [S]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[C*(C*(X/4 + 3*Y/4) + 0.5*S*W) + S*(0.5*C*W + S*Z)]])
# Matrix([[C**2*Y + S**2*Z]])
# Matrix([[C*(C*(X/4 + 3*Y/4) - 0.5*S*W) + S*(-0.5*C*W + S*Z)]])

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
C = Symbol('C')
S = Symbol('S')
R = sympy.Matrix([[0, 3**(0.5)/2, 0.5]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[0], [3**(0.5)/2], [0.5]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[0.433012701892219*W + 0.1875*X + 0.5625*Y + 0.25*Z]])
# Matrix([[0.75*Y + 0.25*Z]])
# Matrix([[-0.433012701892219*W + 0.1875*X + 0.5625*Y + 0.25*Z]])

# %%
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
d = Symbol('d')

def yz1r(x):
    return (c+b)/2+(c-b)/2*np.cos(2*np.radians(x)) + d*np.sin(2*np.radians(x))

def yz1l(x):
    return (c+b)/2+(c-b)/2*np.cos(2*np.radians(x)) - d*np.sin(2*np.radians(x))

def yz23r(x):
    return (4*c+3*a+b)/8+(4*c-(3*a+b))/8*np.cos(2*np.radians(x))-d/2*np.sin(2*np.radians(x))

def yz23l(x):
    return (4*c+3*a+b)/8+(4*c-(3*a+b))/8*np.cos(2*np.radians(x))+d/2*np.sin(2*np.radians(x))

print(yz1r(0))
print(yz23r(0))
# Out:
# 1.0*c
# 1.0*c

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
C = Symbol('C')
S = Symbol('S')
R = sympy.Matrix([[0, 0, 1]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[0], [0], [1]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[Z]])
# Matrix([[Z]])
# Matrix([[Z]])

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
C = Symbol('C')
S = Symbol('S')
R = sympy.Matrix([[S, 0, C]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, 0.5*W], [3**(0.5)*W/2, 0.5*W, Z]])
A2 = sympy.Matrix([[X, 0, W], [0, Y, 0], [W, 0, Z]])
A3 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, 3**(0.5)*W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, -0.5*W], [3**(0.5)*W/2, -0.5*W, Z]])
V = sympy.Matrix([[S], [0], [C]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[C*(C*Z + 0.866025403784439*S*W) + S*(0.866025403784439*C*W + S*(3*X/4 + Y/4))]])
# Matrix([[C*(C*Z + S*W) + S*(C*W + S*X)]])
# Matrix([[C*(C*Z + 0.866025403784439*S*W) + S*(0.866025403784439*C*W + S*(3*X/4 + Y/4))]])

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$yz,1$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-0.6, 0.6])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-0.6, 0.6, 13))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y1(x, 10**(-3)), color='red')
im2 = axes.plot(x, y1(x, 10**(-4)), color='orange')
im3 = axes.plot(x, y1(x, 10**(-5)), color='yellow')
im4 = axes.plot(x, y1(x, 10**(0)), color='green')
im5 = axes.plot(x, y1(x, -10**(-5)), color='blue')
im6 = axes.plot(x, y1(x, -10**(-4)), color='indigo')
im7 = axes.plot(x, y1(x, -10**(-3)), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=0$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$yz,1$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-11, 3])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-11, 3, 15))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y1(x, 10**(-3))*10**(4), color='red')
im2 = axes.plot(x, y1(x, 10**(-4))*10**(4), color='orange')
im3 = axes.plot(x, y1(x, 10**(-5))*10**(4), color='yellow')
# im4 = axes.plot(x, y1(x, 10**(0)), color='green')
im5 = axes.plot(x, y1(x, -10**(-5))*10**(4), color='blue')
im6 = axes.plot(x, y1(x, -10**(-4))*10**(4), color='indigo')
im7 = axes.plot(x, y1(x, -10**(-3))*10**(4), color='purple')

axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$yz,2$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-9, 1])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-9, 1, 11))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y2(x, 10**(-3))*10**(4), color='red')
im2 = axes.plot(x, y2(x, 10**(-4))*10**(4), color='orange')
im3 = axes.plot(x, y2(x, 10**(-5))*10**(4), color='yellow')
im4 = axes.plot(x, y2(x, 10**(0))*10**(4), color='green')
im5 = axes.plot(x, y2(x, -10**(-5))*10**(4), color='blue')
im6 = axes.plot(x, y2(x, -10**(-4))*10**(4), color='indigo')
im7 = axes.plot(x, y2(x, -10**(-3))*10**(4), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=0$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$yz,3$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-0.6, 0.6])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-0.6, 0.6, 13))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y3(x, 10**(-3)), color='red')
im2 = axes.plot(x, y3(x, 10**(-4)), color='orange')
im3 = axes.plot(x, y3(x, 10**(-5)), color='yellow')
im4 = axes.plot(x, y3(x, 10**(0)), color='green')
im5 = axes.plot(x, y3(x, -10**(-5)), color='blue')
im6 = axes.plot(x, y3(x, -10**(-4)), color='indigo')
im7 = axes.plot(x, y3(x, -10**(-3)), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=0$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$yz,3$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-11, 3])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-11, 3, 15))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y3(x, 10**(-3))*10**(4), color='red')
im2 = axes.plot(x, y3(x, 10**(-4))*10**(4), color='orange')
im3 = axes.plot(x, y3(x, 10**(-5))*10**(4), color='yellow')
# im4 = axes.plot(x, y3(x, 10**(0))*10**(4), color='green')
im5 = axes.plot(x, y3(x, -10**(-5))*10**(4), color='blue')
im6 = axes.plot(x, y3(x, -10**(-4))*10**(4), color='indigo')
im7 = axes.plot(x, y3(x, -10**(-3))*10**(4), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$zx,1&3$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-5, 5])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-5, 5, 11))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y4(x, 10**(-3)), color='red')
im2 = axes.plot(x, y4(x, 10**(-4)), color='orange')
im3 = axes.plot(x, y4(x, 10**(-5)), color='yellow')
im4 = axes.plot(x, y4(x, 10**(0)), color='green')
im5 = axes.plot(x, y4(x, -10**(-5)), color='blue')
im6 = axes.plot(x, y4(x, -10**(-4)), color='indigo')
im7 = axes.plot(x, y4(x, -10**(-3)), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=0$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$zx,1&3$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-50, 50])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-50, 50, 11))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y4(x, 10**(-3))*10**(4), color='red')
im2 = axes.plot(x, y4(x, 10**(-4))*10**(4), color='orange')
im3 = axes.plot(x, y4(x, 10**(-5))*10**(4), color='yellow')
# im4 = axes.plot(x, y4(x, 10**(0))*10**(4), color='green')
im5 = axes.plot(x, y4(x, -10**(-5))*10**(4), color='blue')
im6 = axes.plot(x, y4(x, -10**(-4))*10**(4), color='indigo')
im7 = axes.plot(x, y4(x, -10**(-3))*10**(4), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$zx,2$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-1.2, 1.2])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-1.2, 1.2, 25))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y5(x, 10**(-3)), color='red')
im2 = axes.plot(x, y5(x, 10**(-4)), color='orange')
im3 = axes.plot(x, y5(x, 10**(-5)), color='yellow')
im4 = axes.plot(x, y5(x, 10**(0)), color='green')
im5 = axes.plot(x, y5(x, -10**(-5)), color='blue')
im6 = axes.plot(x, y5(x, -10**(-4)), color='indigo')
im7 = axes.plot(x, y5(x, -10**(-3)), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=0$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$zx,2$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-17, 7])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-17, 7, 25))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = 0

def y1(x, t):
    return np.cos(np.radians(x))**(2)*a+0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y2(x, t):
    return np.cos(np.radians(x))**(2)*a+np.sin(np.radians(x))**(2)*b

def y3(x, t):
    return np.cos(np.radians(x))**(2)*a-0.5*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*b

def y4(x, t):
    return np.cos(np.radians(x))**(2)*b+0.5*(3**2)*t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

def y5(x, t):
    return np.cos(np.radians(x))**(2)*b+t*np.sin(2*np.radians(x))+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y5(x, 10**(-3))*10**(4), color='red')
im2 = axes.plot(x, y5(x, 10**(-4))*10**(4), color='orange')
im3 = axes.plot(x, y5(x, 10**(-5))*10**(4), color='yellow')
# im4 = axes.plot(x, y5(x, 10**(0))*10**(4), color='green')
im5 = axes.plot(x, y5(x, -10**(-5))*10**(4), color='blue')
im6 = axes.plot(x, y5(x, -10**(-4))*10**(4), color='indigo')
im7 = axes.plot(x, y5(x, -10**(-3))*10**(4), color='purple')
axes.legend(['$t=10^{-3}$','$t=10^{-4}$', '$t=10^{-5}$', '$t=-10^{-5}$', '$t=-10^{-4}$', '$t=-10^{-3}$'])

plt.show()

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
R = sympy.Matrix([[3**(0.5)/2, 0.5, 0], [-0.5, 3**(0.5)/2, 0], [0, 0, 1]])
A1 = sympy.Matrix([[X, 0, 0], [0, Y, W], [0, W, Z]])
A2 = sympy.Matrix([[(X+3*Y)/4, 3**(0.5)*(X-Y)/4, 3**(0.5)*W/2], [3**(0.5)*(X-Y)/4, (3*X+Y)/4, -W/2], [3**(0.5)*W/2, -W/2, Z]])
A3 = sympy.Matrix([[(X+3*Y)/4, 3**(0.5)*(Y-X)/4, -3**(0.5)*W/2], [3**(0.5)*(Y-X)/4, (3*X+Y)/4, -W/2], [-3**(0.5)*W/2, -W/2, Z]])

f1 = R*A1*(R**(-1))
f2 = R*A2*(R**(-1))
f3 = R*A3*(R**(-1))

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[0.75*X + 0.25*Y, -0.433012701892219*X + 0.433012701892219*Y, 0.5*W], [-0.433012701892219*X + 0.433012701892219*Y, 0.25*X + 0.75*Y, 0.866025403784439*W], [0.5*W, 0.866025403784439*W, Z]])
# Matrix([[0.75*X + 0.25*Y, 0.433012701892219*X - 0.433012701892219*Y, 0.5*W], [0.433012701892219*X - 0.433012701892219*Y, 0.25*X + 0.75*Y, -0.866025403784439*W], [0.5*W, -0.866025403784439*W, Z]])
# Matrix([[2.77555756156289e-17*X + 1.0*Y, 4.80740671595891e-17*X - 1.11022302462516e-16*Y, -1.0*W], [1.11022302462516e-16*X - 4.80740671595891e-17*Y, 1.0*X + 2.77555756156289e-17*Y, 0], [-1.0*W, 5.55111512312578e-17*W, Z]])

# %%
X = Symbol('X')
Y = Symbol('Y')
Z = Symbol('Z')
W = Symbol('W')
C = Symbol('C')
S = Symbol('S')
R = sympy.Matrix([[C, S, 0]])
A1 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(-X+Y)/4, W/2], [3**(0.5)*(-X+Y)/4, (X+3*Y)/4, 3**(0.5)*W/2], [W/2, 3**(0.5)*W/2, Z]])
A2 = sympy.Matrix([[(3*X+Y)/4, 3**(0.5)*(X-Y)/4, W/2], [3**(0.5)*(X-Y)/4, (X+3*Y)/4, -3**(0.5)*W/2], [W/2, -3**(0.5)*W/2, Z]])
A3 = sympy.Matrix([[Y, 0, -W], [0, X, 0], [-W, 0, Z]])
V = sympy.Matrix([[C], [S], [0]])

f1 = R*A1*V
f2 = R*A2*V
f3 = R*A3*V

print(f1)
print(f2)
print(f3)
# Out:
# Matrix([[C*(C*(3*X/4 + Y/4) + S*(-0.433012701892219*X + 0.433012701892219*Y)) + S*(C*(-0.433012701892219*X + 0.433012701892219*Y) + S*(X/4 + 3*Y/4))]])
# Matrix([[C*(C*(3*X/4 + Y/4) + S*(0.433012701892219*X - 0.433012701892219*Y)) + S*(C*(0.433012701892219*X - 0.433012701892219*Y) + S*(X/4 + 3*Y/4))]])
# Matrix([[C**2*Y + S**2*X]])

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$xy$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-10, 10])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-10, 10, 11))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = (1.146)*10**(-4)
c = 0
d = (8.830)*10**(-4)

def y1(x):
    return np.cos(np.radians(x))*(np.cos(np.radians(x))*(3*a/4 + b/4) + np.sin(np.radians(x))*(-3**(0.5)*a/4 + 3**(0.5)*b/4)) + np.sin(np.radians(x))*(np.cos(np.radians(x))*(-3**(0.5)*a/4 + 3**(0.5)*b/4) + np.sin(np.radians(x))*(a/4 + 3*b/4))

def y2(x):
    return np.cos(np.radians(x))*(np.cos(np.radians(x))*(3*a/4 + b/4) + np.sin(np.radians(x))*(3**(0.5)*a/4 - 3**(0.5)*b/4)) + np.sin(np.radians(x))*(np.cos(np.radians(x))*(3**(0.5)*a/4 - 3**(0.5)*b/4) + np.sin(np.radians(x))*(a/4 + 3*b/4))

def y3(x):
    return np.cos(np.radians(x))**(2)*b+np.sin(np.radians(x))**(2)*a

ims=[]
im1 = axes.plot(x, y1(x)*10**(4), color='red')
im2 = axes.plot(x, y2(x)*10**(4), color='blue')
im3 = axes.plot(x, y3(x)*10**(4), color='green')

axes.legend(['$1$','$2$', '$3$'])

plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$xy$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-10, 10])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-10, 10, 11))
axes.grid()

x = np.linspace(0, 180, 100)

a = (-8.572)*10**(-4)
b = (1.146)*10**(-4)
c = 0
d = (8.830)*10**(-4)

def y1(x):
    return np.cos(np.radians(x))*(np.cos(np.radians(x))*(3*a/4 + b/4) + np.sin(np.radians(x))*(-3**(0.5)*a/4 + 3**(0.5)*b/4)) + np.sin(np.radians(x))*(np.cos(np.radians(x))*(-3**(0.5)*a/4 + 3**(0.5)*b/4) + np.sin(np.radians(x))*(a/4 + 3*b/4))

def y2(x):
    return np.cos(np.radians(x))*(np.cos(np.radians(x))*(3*a/4 + b/4) + np.sin(np.radians(x))*(3**(0.5)*a/4 - 3**(0.5)*b/4)) + np.sin(np.radians(x))*(np.cos(np.radians(x))*(3**(0.5)*a/4 - 3**(0.5)*b/4) + np.sin(np.radians(x))*(a/4 + 3*b/4))

def y3(x):
    return np.cos(np.radians(x))**(2)*b+np.sin(np.radians(x))**(2)*a

def xy1(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x))

def xy2r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

def xy2l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3r(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def xy3l(x):
    return (a+b)/2+(a-b)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

ims=[]
im1 = axes.plot(x, y1(x)*10**(4), color='red')
im2 = axes.plot(x, y2(x)*10**(4), color='blue')
im3 = axes.plot(x, y3(x)*10**(4), color='green')
im4 = axes.plot(x, xy1(x)*10**(4), ":", color='red')
im5 = axes.plot(x, xy2r(x)*10**(4), ":", color='blue')
im6 = axes.plot(x, xy3r(x)*10**(4), ":", color='green')

axes.legend(['$1$','$2$', '$3$', '$1-$','$2-$', '$3-$'])

plt.show()

# %%
n1 = 0
n2 = 0
n3 = 1
s1 = 1
s2 = 0
s3 = 0
C = Symbol('C')
S = Symbol('S')

T = sympy.Matrix([[n1**(2)*(1-C)+C, n1*n2*(1-C)-n3*S, n1*n3*(1-C)+n2*S], 
            [n1*n2*(1-C)+n3*S, n2**(2)*(1-C)+C, n2*n3*(1-C)-n1*S], 
            [n1*n3*(1-C)-n2*S, n2*n3*(1-C)+n1*S, n3**(2)*(1-C)+C]])

s = sympy.Matrix([[s1], [s2], [s3]])
S = sympy.Matrix([[s1, s2, s3]])

h = T*s

print(h)
# Out:
# Matrix([[C], [S], [0]])

# %%
C = Symbol('C')
S = Symbol('S')

k_0 = Symbol('k_0')
k_U = Symbol('k_U')
k_V = Symbol('k_V')
k_X = Symbol('k_X')
k_Y = Symbol('k_Y')
k_Z = Symbol('k_Z')
XX = Symbol('XX')
XY = Symbol('XY')
YY = Symbol('YY')
YZ = Symbol('YZ')
ZZ = Symbol('ZZ')
ZX = Symbol('ZX')

K = sympy.Matrix([[XX, XY, ZX], [XY, YY, YZ], [ZX, YZ, ZZ]])

R2 = Matrix([[np.cos(np.radians(-120)), -np.sin(np.radians(-120)), 0], [np.sin(np.radians(-120)), np.cos(np.radians(-120)), 0], [0, 0, 1]])
R3 = Matrix([[np.cos(np.radians(120)), -np.sin(np.radians(120)), 0], [np.sin(np.radians(120)), np.cos(np.radians(120)), 0], [0, 0, 1]])

H = sympy.Matrix([[C, S, 0]]) 
h = sympy.Matrix([[C], [S], [0]])

K1 = H*K*h
K2 = H*R2*K*R2**(-1)*h
K3 = H*R3*K*R3**(-1)*h

print(K1)
print(K2)
print(K3)
# Out:
# Matrix([[C*(C*XX + S*XY) + S*(C*XY + S*YY)]])
# Matrix([[C*(-0.5*XX*(-0.5*C - 0.866025403784439*S) + 0.866025403784439*XY*(-0.5*C - 0.866025403784439*S) - 0.5*XY*(0.866025403784439*C - 0.5*S) + 0.866025403784439*YY*(0.866025403784439*C - 0.5*S)) + S*(-0.866025403784439*XX*(-0.5*C - 0.866025403784439*S) - 0.5*XY*(-0.5*C - 0.866025403784439*S) - 0.866025403784439*XY*(0.866025403784439*C - 0.5*S) - 0.5*YY*(0.866025403784439*C - 0.5*S))]])
# Matrix([[C*(-0.5*XX*(-0.5*C + 0.866025403784439*S) - 0.5*XY*(-0.866025403784439*C - 0.5*S) - 0.866025403784439*XY*(-0.5*C + 0.866025403784439*S) - 0.866025403784439*YY*(-0.866025403784439*C - 0.5*S)) + S*(0.866025403784439*XX*(-0.5*C + 0.866025403784439*S) + 0.866025403784439*XY*(-0.866025403784439*C - 0.5*S) - 0.5*XY*(-0.5*C + 0.866025403784439*S) - 0.5*YY*(-0.866025403784439*C - 0.5*S))]])

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), constrained_layout=True)
axes.set_title(r"$xy$")
axes.set_xlabel(r"$Rotation \quad angle$", fontsize=15) 
axes.set_ylabel(r"$Knight \quad shift(\times 10^{4})$", fontsize=15)

axes.set_xlim([0, 180])
axes.set_ylim([-10, 10])
axes.set_xticks(np.linspace(0, 180, 10))
axes.set_yticks(np.linspace(-10, 10, 11))
axes.grid()

x = np.linspace(0, 180, 100)

XX = (-8.572)*10**(-4)
YY = (1.146)*10**(-4)
ZZ = 0
XY = 0
YZ = (8.830)*10**(-4)
ZX = 0
C = np.cos(np.radians(x))
S = np.sin(np.radians(x))

def xy1(x):
    return C*(C*XX + S*XY) + S*(C*XY + S*YY)

def xy2(x):
    return C*(-0.5*XX*(-0.5*C - 0.866025403784439*S) + 0.866025403784439*XY*(-0.5*C - 0.866025403784439*S) - 0.5*XY*(0.866025403784439*C - 0.5*S) + 0.866025403784439*YY*(0.866025403784439*C - 0.5*S)) + S*(-0.866025403784439*XX*(-0.5*C - 0.866025403784439*S) - 0.5*XY*(-0.5*C - 0.866025403784439*S) - 0.866025403784439*XY*(0.866025403784439*C - 0.5*S) - 0.5*YY*(0.866025403784439*C - 0.5*S))

def xy3(x):
    return C*(-0.5*XX*(-0.5*C + 0.866025403784439*S) - 0.5*XY*(-0.866025403784439*C - 0.5*S) - 0.866025403784439*XY*(-0.5*C + 0.866025403784439*S) - 0.866025403784439*YY*(-0.866025403784439*C - 0.5*S)) + S*(0.866025403784439*XX*(-0.5*C + 0.866025403784439*S) + 0.866025403784439*XY*(-0.866025403784439*C - 0.5*S) - 0.5*XY*(-0.5*C + 0.866025403784439*S) - 0.5*YY*(-0.866025403784439*C - 0.5*S))

def XY1(x):
    return (XX+YY)/2+(XX-YY)/2*np.cos(2*np.radians(x))

def XY2r(x):
    return (XX+YY)/2+(XX-YY)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

def XY2l(x):
    return (XX+YY)/2+(XX-YY)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def XY3r(x):
    return (XX+YY)/2+(XX-YY)/2*np.cos(2*np.radians(x) - np.pi * 4/3 )

def XY3l(x):
    return (XX+YY)/2+(XX-YY)/2*np.cos(2*np.radians(x) + np.pi * 4/3 )

ims=[]
im1 = axes.plot(x, xy1(x)*10**(4), color='red')
im2 = axes.plot(x, xy2(x)*10**(4), color='blue')
im3 = axes.plot(x, xy3(x)*10**(4), color='green')
im4 = axes.plot(x, XY1(x)*10**(4), ":", color='red')
im5 = axes.plot(x, XY2r(x)*10**(4), ":", color='blue')
im6 = axes.plot(x, XY3r(x)*10**(4), ":", color='green')

axes.legend(['$1$','$2$', '$3$', '$1-$','$2-$', '$3-$'])

plt.show()
